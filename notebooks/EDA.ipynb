# %%
import pandas as pd

# %%
df = pd.read_csv('../data/scraped_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   advertiser_code              30 non-null     object
#  1   advertiser_creci             23 non-null     object
#  2   advertiser_is_premium        30 non-null     bool
#  3   advertiser_name              30 non-null     object
#  4   advertiser_properties_count  30 non-null     int64
#  5   advertiser_since_date        29 non-null     object
#  6   amenities                    24 non-null     object
#  7   area                         30 non-null     float64
#  8   bathrooms                    29 non-null     float64
#  9   bedrooms                     29 non-null     float64
#  10  condo_fee                    14 non-null     float64
#  11  created_date                 30 non-null     object
#  12  description                  30 non-null     object
# ...
